# %% [markdown]
# ## PCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('wine.csv')

# %%
df.shape
# Out:
# (178, 14)

# %%
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
### missing values
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(15,10))
df.boxplot()
plt.show()

# %%
### outlier capping
def outlier_capping(df,column):
    Q1= df[column].quantile(0.25)
    Q3= df[column].quantile(0.75)
    IQR= Q3-Q1
    lower_extreme= Q1-1.5*IQR
    upper_extreme= Q3+1.5*IQR
    df[column]= df[column].apply(lambda x: lower_extreme if x<lower_extreme else upper_extreme if x>upper_extreme else x)
for col in df.select_dtypes(['int','float']).columns:
    outlier_capping(df,col)

# %%
plt.figure(figsize=(15,10))
df.boxplot()
plt.show()

# %%
# Histogram
df.hist(figsize=(10,10))
plt.show()

# %%
### correlation
corr=df.corr()
corr
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.440422 -0.047680    0.525608
# Alcohol         -0.328222  1.000000  0.094756  0.220174   -0.312191
# Malic            0.440422  0.094756  1.000000  0.166614    0.295882
# Ash             -0.047680  0.220174  0.166614  1.000000    0.427713
# Alcalinity       0.525608 -0.312191  0.295882  0.427713    1.000000
# Magnesium       -0.224264  0.302173 -0.039329  0.322510   -0.098030
# Phenols         -0.719163  0.289101 -0.339050  0.124436   -0.333046
# Flavanoids      -0.847498  0.236815 -0.414875  0.097562   -0.363405
# Nonflavanoids    0.489109 -0.155929  0.294203  0.183666    0.369276
# Proanthocyanins -0.512528  0.153171 -0.234575  0.006080   -0.208794
# Color            0.260260  0.549107  0.264897  0.256799    0.009748
# Hue             -0.621549 -0.067156 -0.566409 -0.075904   -0.286664
# Dilution        -0.788230  0.072343 -0.372582 -0.011214   -0.287032
# ...

# %%
# Heatmap
plt.figure(figsize=(15,15))
sns.heatmap(corr,annot=True)
plt.show()

# %%
target=df[['Type']]
features=df.drop(columns=['Type'])
features.columns
# Out:
# Index(['Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
### Standardize the features
std_scaler=StandardScaler()
features[['Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
       'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
       'Dilution', 'Proline']]=std_scaler.fit_transform(features[['Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
       'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
       'Dilution', 'Proline']])

# %%
features.head()
# Out:
#     Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  Flavanoids  \
# 0  1.518613 -0.565534  0.240640   -1.182882   2.057111  0.808997    1.034819
# 1  0.246290 -0.501728 -0.862176   -2.524956   0.038639  0.568648    0.733629
# 2  0.196879  0.026948  1.153315   -0.267832   0.113397  0.808997    1.215533
# 3  1.691550 -0.346771  0.506837   -0.816862   1.010496  2.491446    1.466525
# 4  0.295700  0.236596  1.913878    0.464208   1.384287  0.808997    0.663351
#
#    Nonflavanoids  Proanthocyanins     Color       Hue  Dilution   Proline
# 0      -0.659563         1.264740  0.266954  0.366610  1.847920  1.013009
# 1      -0.820719        -0.549904 -0.291923  0.410768  1.113449  0.965242
# 2      -0.498407         2.199012  0.284696  0.322451  0.788587  1.395148
# 3      -0.981875         1.067105  1.225029 -0.428246  1.184071  2.334574
# 4       0.226796         0.420301 -0.318536  0.366610  0.449601 -0.037874

# %%
pca = PCA()
pca.fit(features)
# Out:
# PCA()

# %%
plt.figure(figsize=(8,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Components')
plt.grid(True)
plt.show()

# %%
pca=PCA(n_components=10)
X_pca = pca.fit_transform(features)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans=KMeans(n_clusters=3)
cluster=kmeans.fit(features)

# %%
np.unique(cluster.labels_)
# Out:
# array([0, 1, 2], dtype=int32)

# %%
df['Cluster'] = cluster.labels_
df[df.Cluster==0]
# Out:
#      Type  Alcohol  Malic      Ash  Alcalinity  Magnesium  Phenols  \
# 59      2    12.37   0.94  1.68875       10.75       88.0     1.98
# 60      2    12.33   1.10  2.28000       16.00      101.0     2.05
# 62      2    13.67   1.25  1.92000       18.00       94.0     2.10
# 63      2    12.37   1.13  2.16000       19.00       87.0     3.50
# 64      2    12.17   1.45  2.53000       19.00      104.0     1.89
# ..    ...      ...    ...      ...         ...        ...      ...
# 125     2    12.07   2.16  2.17000       21.00       85.0     2.60
# 126     2    12.43   1.53  2.29000       21.50       86.0     2.74
# 127     2    11.79   2.13  2.78000       27.95       92.0     2.13
# 128     2    12.37   1.63  2.30000       24.50       88.0     2.22
# 129     2    12.04   4.30  2.38000       22.00       80.0     2.10
#
#      Flavanoids  Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  \
# 59         0.57           0.28             0.42   1.95  1.05      1.82
# ...

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(features)

# %%
#  DataFrame with PCA results and cluster labels
pca_df = pd.DataFrame(data = X_pca, columns = ['principal component 1', 'principal component 2'])
pca_df['Cluster'] = cluster.labels_
plt.figure(figsize=(10,8))
sns.lmplot(data=pca_df, x='principal component 1', y='principal component 2', hue='Cluster', palette='viridis', scatter_kws={'s': 60})
plt.title('K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
silhouette_score(features,cluster.labels_)
# Out:
# 0.2854626783251893

# %%
kmeans=KMeans(n_clusters=3, random_state=100)
cluster_pca=kmeans.fit(X_pca)

# %%
np.unique(cluster.labels_)
# Out:
# array([0, 1, 2], dtype=int32)

# %%
df['Cluster_PCA']=cluster_pca.labels_

# %%
df[df.Cluster_PCA==1]
# Out:
#      Type  Alcohol  Malic      Ash  Alcalinity  Magnesium  Phenols  \
# 0       1    14.23   1.71  2.43000       15.60      127.0     2.80
# 1       1    13.20   1.78  2.14000       11.20      100.0     2.65
# 2       1    13.16   2.36  2.67000       18.60      101.0     2.80
# 3       1    14.37   1.95  2.50000       16.80      113.0     3.85
# 4       1    13.24   2.59  2.87000       21.00      118.0     2.80
# ..    ...      ...    ...      ...         ...        ...      ...
# 73      2    12.99   1.67  2.60000       27.95      135.5     3.30
# 78      2    12.33   0.99  1.95000       14.80      135.5     1.90
# 95      2    12.47   1.52  2.20000       19.00      135.5     2.50
# 98      2    12.37   1.07  2.10000       18.50       88.0     3.52
# 121     2    11.56   2.05  3.07875       27.95      119.0     3.18
#
#      Flavanoids  Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  \
# 0          3.06           0.28             2.29   5.64  1.04      3.92
# ...

# %%
# DataFrame with PCA results and cluster labels from PCA clustering
pca_df_pca_clusters = pd.DataFrame(data = X_pca, columns = ['principal component 1', 'principal component 2'])
pca_df_pca_clusters['Cluster_PCA'] = cluster_pca.labels_

sns.lmplot(data=pca_df_pca_clusters, x='principal component 1', y='principal component 2', hue='Cluster_PCA', palette='viridis', scatter_kws={'s': 60})
plt.title('K-Means Clustering (2D PCA Projection with PCA Clusters)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster_PCA')
plt.show()

# %%
silhouette_pca = silhouette_score(X_pca, cluster_pca.labels_)
silhouette_pca
# Out:
# 0.5619178058700298

# %% [markdown]
# ##### Compare the clustering results obtained from the original dataset and PCA-transformed data.

# %% [raw]
#  K-Means clustering on both the original dataset and PCA-transformed data (with 10 PCs) produced similar cluster structures. However, PCA-transformed data resulted in more compact and separable clusters, making them easier to interpret in 2D space while retaining most of the dataset's variance.

# %% [markdown]
# ##### Discuss any similarities or differences observed in the clustering results.

# %% [raw]
# Both original and PCA-based clustering show 3 main clusters, preserving group separability. PCA-based clustering has slightly better silhouette score, indicating improved cluster compactness and separation.

# %% [markdown]
# ##### Reflect on the impact of dimensionality reduction on clustering performance.

# %% [raw]
# Improved cluster compactness and separation,retained underlying structure of the data, preserving the natural groupings,simplified and more interpretable clusters in lower-dimensional space.

# %% [markdown]
# ##### Analyze the trade-offs between using PCA and clustering directly on the original dataset.

# %% [raw]
# Using PCA before clustering can improve computational efficiency and noise reduction, but may lose some information, whereas clustering directly on the original dataset retains all information but might be computationally expensive and sensitive to noise.PCA seems to have improved clustering quality, but the choice depends on the specific dataset and goals.

# %% [markdown]
# ##### Summarize the key findings and insights from the assignment.

# %% [markdown]
# Dimensionality reduction via PCA enhanced cluster compactness and separation, PCA preserved the natural groupings in the wine dataset, PCA reduced noise and improved efficiency but may lose some information, Both original and PCA-based clustering showed similar cluster formations.The silhouette score improved slightly, confirming that PCA helped in forming more cohesive and well-separated clusters.

# %% [markdown]
# ##### Discuss the practical implications of using PCA and clustering in data analysis.

# %% [raw]
# PCA and clustering enable data simplification, pattern discovery, and informed decision-making in various fields like marketing, healthcare, and finance by reducing dimensionality and identifying natural groupings.

# %% [markdown]
# ##### Provide recommendations for when to use each technique based on the analysis conducted.

# %% [raw]
# Use PCA for dimensionality reduction and noise filtering, and clustering for identifying natural groupings, combining both for enhanced insights in high-dimensional data analysis.
