# %% [markdown]
# ## Basic Statistics

# %% [markdown]
# #### Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset

# %%
import pandas as pd

# %%
df=pd.read_csv('sales_data_with_discounts.csv')

# %%
df.shape
# Out:
# (450, 13)

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
num_col=[i for i in df.columns if df[i].dtype in ['int','float']]
num_col
# Out:
# ['Volume',
#  'Avg Price',
#  'Total Sales Value',
#  'Discount Rate (%)',
#  'Discount Amount',
#  'Net Sales Value']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# #### Mean

# %%
df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %% [markdown]
# #### Median

# %%
df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].median()
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %% [markdown]
# #### Mode

# %%
df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].mode().iloc[0]
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %% [markdown]
# #### Standard Deviation

# %%
df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].std()
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#### 10000 is the common average price of the item sold and average sales is 33000 and have an average discount of 15% so the discont have a role in total sales

# %% [markdown]
# #### Data visualization

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import skew

# %% [markdown]
# ### Histogram

# %%
plt.hist(df.Volume)
print(df['Volume'].skew())
plt.show()
### positive skewness- data is skewed towards right side
# Out:
# 2.731723626557714

# %%
plt.hist(df['Avg Price'])
print(df['Avg Price'].skew())
plt.show()
### positive skewness- data is skewed towards right side
# Out:
# 1.9088730767759727

# %%
plt.hist(df['Total Sales Value'])
print(df["Total Sales Value"].skew())
plt.show
### positive skewness- data is skewed towards right side
# Out:
# 1.5347293238977937
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df['Discount Amount'])
print(df['Discount Amount'].skew())
### positive skewness- data is skewed towards right side
# Out:
# 1.9130377339538271

# %%
plt.hist(df['Discount Rate (%)'])
print(df['Discount Rate (%)'].skew())
### negative skewness-data is skewed towards left side
# Out:
# -1.0622943696988825

# %%
plt.hist(df['Net Sales Value'])
print(df['Net Sales Value'].skew())
### positive skewness- data is skewed towards right side
# Out:
# 1.5408217575344376

# %% [markdown]
# ### Boxplot

# %%
plt.boxplot(df['Volume'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218b1535bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218b1537b10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218b1535d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x218b1537ed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218b1537d90>],
#  'means': []}

# %%
plt.boxplot(df['Avg Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218b1d1dbd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218b1d1de50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218b1d1da90>],
#  'medians': [<matplotlib.lines.Line2D at 0x218b1d1e0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218b1d1e210>],
#  'means': []}

# %%
plt.boxplot(df['Total Sales Value'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218b1d916d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218b1d91950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218b1d91590>],
#  'medians': [<matplotlib.lines.Line2D at 0x218b1d91bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218b1d91d10>],
#  'means': []}

# %%
plt.boxplot(df['Discount Amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218b1dfe0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218b1dfe350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218b1dfdf90>],
#  'medians': [<matplotlib.lines.Line2D at 0x218b1dfe5d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218b1dfe710>],
#  'means': []}

# %%
plt.boxplot(df['Discount Rate (%)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218b1ea91d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218b1ea9450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218b1ea9090>],
#  'medians': [<matplotlib.lines.Line2D at 0x218b1ea96d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218b1ea9810>],
#  'means': []}

# %%
plt.boxplot(df['Net Sales Value'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218b13ddd10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x218b1507d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x218b13dde50>],
#  'medians': [<matplotlib.lines.Line2D at 0x218b1506fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218b1506e90>],
#  'means': []}

# %% [markdown]
# ### Barchart

# %%
cat_col=[col for col in df.columns if df[col].dtype in ['category','object']]
cat_col
# Out:
# ['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# %%
plt.bar(df.BU,df.Volume)
# Out:
# <BarContainer object of 450 artists>

# %%
plt.bar(df.Brand,df.Volume)
# Out:
# <BarContainer object of 450 artists>

# %%
plt.bar(df.Model,df.Volume)
# Out:
# <BarContainer object of 450 artists>

# %%
plt.bar(df.BU,df['Net Sales Value'])
# Out:
# <BarContainer object of 450 artists>

# %%
plt.bar(df.Brand,df['Net Sales Value'])
# Out:
# <BarContainer object of 450 artists>

# %%
plt.bar(df.Model,df['Net Sales Value'])
# Out:
# <BarContainer object of 450 artists>

# %%
### the most sold item is fmcg and least is mobiles
### but the net sales value is higher for mobiles
### the babaji brand has high demand
### the net turnover
sum(df['Net Sales Value'])
# Out:
# 13709851.259071562
